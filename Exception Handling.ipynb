# %%
print('dgf) #compile time error
# Out:
#   File "<ipython-input-4-728986c318df>", line 1
#     print('dgf) #compile time error
#                                    ^
# SyntaxError: EOL while scanning string literal

# %%
def test(a,b): #run time error
    return a/b
test(5,0)
print('okay')
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-7-4c4dfd80fcee> in <module>
#       1 def test(a,b): #run time error
#       2     return a/b
# ----> 3 test(5,0)
#       4 print('okay')
#
# <ipython-input-7-4c4dfd80fcee> in test(a, b)
#       1 def test(a,b): #run time error
# ----> 2     return a/b
#       3 test(5,0)
#       4 print('okay')
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ### We always handle run time errors

# %%
a=open('test.txt', 'r')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-814d663b530f> in <module>
# ----> 1 a=open('test.txt', 'r')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test.txt'

# %%
try:
    a=open('test.txt', 'r')
# Out:
#   File "<ipython-input-9-28fd65704c5c>", line 2
#     a=open('test.txt', 'r')
#                            ^
# SyntaxError: unexpected EOF while parsing

# %%
try:
    a=open('test.txt', 'r')
except: 
    pass

# %% [markdown]
# here we will get error because, this is syntax error (compile time error) and using try- except we can only handle run time error

# %%
try:
    a=open('test.txt', 'r'
except: 
    pass
# Out:
#   File "<ipython-input-11-683ba2ecaa58>", line 3
#     except:
#     ^
# SyntaxError: invalid syntax

# %%
try:
    a=open('test.txt', 'r')
except: 
    print("there is an issue, please check")
# Out:
# there is an issue, please check

# %%
try:
    a=open('test.txt', 'r')
except IOError: 
    print("there is an issue, please check")
# Out:
# there is an issue, please check

# %%
try:
    5/0
except IOError: 
    print("there is an issue, please check")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-16-ec488dfeb942> in <module>
#       1 try:
# ----> 2     5/0
#       3 except IOError:
#       4     print("there is an issue, please check")
#
# ZeroDivisionError: division by zero

# %%
try:
    5/0
except ArithmeticError: 
    print("there is an issue, please check")
# Out:
# there is an issue, please check

# %%
try:
    5/0
except ArithmeticError as e: 
    print("there is an issue, please check. ",e)
# Out:
# there is an issue, please check.  division by zero

# %%
try:
    a=5/4
except ArithmeticError as e: 
    print("there is an issue, please check. ",e)
else:
    print("this will execute when try block is successful")
# Out:
# this will execute when try block is successful

# %%
try:
    a=5/4
except ArithmeticError as e: 
    print("there is an issue, please check. ",e)
else:
    print("this will execute when try block is successful")
    f=open('test.txt')
# Out:
# this will execute when try block is successful
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-25-1d8c1269d6fb> in <module>
#       5 else:
#       6     print("this will execute when try block is successful")
# ----> 7     f=open('test.txt')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test.txt'

# %%
try:
    a=5/4
except ArithmeticError as e: 
    print("there is an issue, please check. ",e)
else:
    print("this will execute when try block is successful")
    try:
        f=open('test.txt')
    except:
        print("ther is an issue in the try of else block")
# Out:
# this will execute when try block is successful
# ther is an issue in the try of else block

# %%
try:
    a=5/0
except ArithmeticError as e: 
    print("there is an issue, please check. ",e)
    f=open('check.txt','w')
else:
    print("this will execute when try block is successful")
    try:
        f=open('test.txt')
    except:
        print("ther is an issue in the try of else block")
# Out:
# there is an issue, please check.  division by zero

# %%
try:
    a= int(input("enter the first number: "))
    b= int(input("enter the second number: "))
    c=a/b
except ArithmeticError as e: 
    print("there is an issue, please check. ",e)
    f=open('check.txt','w')
else:
    print("this will execute when try block is successful")
    try:
        f=open('check.txt','r')
    except:
        print("ther is an issue in the try of else block")
# Out:
# enter the first number: 4
# enter the second number: 4
# this will execute when try block is successful

# %%
try:
    a= int(input("enter the first number: "))
    b= int(input("enter the second number: "))
    c=a/b
except ArithmeticError as e: 
    print("there is an issue, please check. ",e)
    f=open('check.txt','w')
else:
    print("this will execute when try block is successful")
    try:
        f=open('check.txt','r')
    except:
        print("ther is an issue in the try of else block")
# Out:
# enter the first number: 5
# enter the second number: 0
# there is an issue, please check.  division by zero

# %%
lst=[4,5,6,1,2]
print(lst[100])
t=(4,5,6)
print(t)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-323933849b97> in <module>
#       1 lst=[4,5,6,1,2]
# ----> 2 print(lst[100])
#       3 t=(4,5,6)
#       4 print(t)
#
# IndexError: list index out of range

# %%
try:
    lst=[4,5,6,1,2]
    print(lst[100])
except:
    print("there is an error")
    t=(4,5,6)
    print(t)
else:
    print("no issue with the code")
# Out:
# there is an error
# (4, 5, 6)

# %%
lst=[4,5,6,1,2]
t=(4,5,6)
print(t)
t[0]='krish'
# Out:
# (4, 5, 6)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-d8304c1493ee> in <module>
#       2 t=(4,5,6)
#       3 print(t)
# ----> 4 t[0]='krish'
#
# TypeError: 'tuple' object does not support item assignment

# %%
try:
    lst=[4,5,6,1,2]
    print(lst[100])
except:
    print("there is an error")
    t=(4,5,6)
    print(t)
    try:
        t[0]='krish'
    except:
        pass
else:
    print("no issue with the code")
# Out:
# there is an error
# (4, 5, 6)

# %%
try:
    f=open('test.txt','r')
finally:
    print("this will get printed in any situations --- even if try is pass or fail")
# Out:
# this will get printed in any situations --- even if try is pass or fail
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-13f566779d6e> in <module>
#       1 try:
# ----> 2     f=open('test.txt','r')
#       3 finally:
#       4     print("this will get printed in any situations --- even if try is pass or fail")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test.txt'

# %%
try:
    f=open('test.txt','r')
except:
    pass
else:
    print("else will execute if tyy is pass")
finally:
    print("this will get printed in any situations --- even if try is pass or fail")
    l=[1,2,3]
    try:
        print(l[45])
    except:
        pass
# Out:
# this will get printed in any situations --- even if try is pass or fail

# %%
try:
    f=open('test.txt','w')
except:
    pass
else:
    print("else will execute if try is pass")
finally:
    print("this will get printed in any situations --- even if try is pass or fail")
    l=[1,2,3]
    try:
        print(l[45])
    except:
        pass
# Out:
# else will execute if try is pass
# this will get printed in any situations --- even if try is pass or fail

# %%
5/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-2-0106664d39e8> in <module>
# ----> 1 5/0
#
# ZeroDivisionError: division by zero

# %%
try:
    f=open('testtt.txt','r')
except IOError:
    print("This is an error")
# Out:
# This is an error

# %%
try:
    f=open('testtt.txt','r')
except IOError as e :
    print("This is an error.", e)
# Out:
# This is an error. [Errno 2] No such file or directory: 'testtt.txt'

# %%
def askforint():
    while True:
        try:
            a=int(input("enter an int: "))     
        except Exception as e:
            print("error:", e)
        else:
            print("entered integer")
        finally:
            print('all done')
askforint()
# Out:
# enter an int: 4
# entered integer
# all done
# enter an int: fed
# error: invalid literal for int() with base 10: 'fed'
# all done
# enter an int: 4
# entered integer
# all done
# all done
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-37c6489158c5> in <module>
#       9         finally:
#      10             print('all done')
# ---> 11 askforint()
#
# <ipython-input-16-37c6489158c5> in askforint()
#       2     while True:
#       3         try:
# ----> 4             a=int(input("enter an int: "))
#       5         except Exception as e:
#       6             print("error:", e)
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
def askforint():
    while True:
        try:
            a=int(input("enter an int: "))     
        except Exception as e:
            print("error:", e)
        else:
            print("entered integer")
            break
        finally:
            print('all done')
askforint()
# Out:
# enter an int: 6
# entered integer
# all done

# %%
def askforint():
    while True:
        try:
            a=int(input("enter an int: "))     
        except Exception as e:
            print("error:", e)
        else:
            print("entered integer")
            break
        finally:
            print('all done')
askforint()
# Out:
# enter an int: egf
# error: invalid literal for int() with base 10: 'egf'
# all done
# enter an int: 4
# entered integer
# all done

# %%
def askforint():
    while True:
        try:
            a=int(input("enter an int: "))     
        except FileNotFoundError as e:
            print("error:", e)
            continue
        except IOError as e:
                print(e)
        else:
            print("entered integer")
            break
        finally:
            print('all done')
askforint()
# Out:
# enter an int: gjh
# all done
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-8b36c04872a4> in <module>
#      13         finally:
#      14             print('all done')
# ---> 15 askforint()
#
# <ipython-input-18-8b36c04872a4> in askforint()
#       2     while True:
#       3         try:
# ----> 4             a=int(input("enter an int: "))
#       5         except FileNotFoundError as e:
#       6             print("error:", e)
#
# ValueError: invalid literal for int() with base 10: 'gjh'

# %%
def askforint():
    while True:
        try:
            a=int(input("enter an int: "))     
        except FileNotFoundError as e:
            print("error:", e)
        except IOError as e:
                print(e)
        except ValueError as e:
            print("value error. ",e)
        else:
            print("entered integer")
            break
        finally:
            print('all done')
askforint()
# Out:
# enter an int: fre
# value error.  invalid literal for int() with base 10: 'fre'
# all done
# enter an int: 4
# entered integer
# all done

# %%
def askforint():
    while True:
        try:
            a=int(input("enter an int: "))  
            c=5/a
        except FileNotFoundError as e:
            print("error:", e)
        except IOError as e:
                print(e)
        except ValueError as e:
            print("value error. ",e)
        else:
            print("entered integer")
            break
        finally:
            print('all done')
askforint()
# Out:
# enter an int: 0
# all done
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-3-9b762f6dcc56> in <module>
#      15         finally:
#      16             print('all done')
# ---> 17 askforint()
#
# <ipython-input-3-9b762f6dcc56> in askforint()
#       3         try:
#       4             a=int(input("enter an int: "))
# ----> 5             c=5/a
#       6         except FileNotFoundError as e:
#       7             print("error:", e)
#
# ZeroDivisionError: division by zero

# %%
def askforint():
    while True:
        try:
            a=int(input("enter an int: "))  
            c=5/a
        except FileNotFoundError as e:
            print("error:", e)
        except IOError as e:
                print(e)
        except ArithmeticError as e:
            print("Ar error. ",e)
        except ZeroDivisionError as e:
            print(e)    
        else:
            print("entered integer")
            break
        finally:
            print('all done')
askforint()
# Out:
# enter an int: 0
# Ar error.  division by zero
# all done
# enter an int: 5
# entered integer
# all done

# %%
def askforint():
    while True:
        try:
            a=int(input("enter an int: "))  
            c=5/a
        except FileNotFoundError as e:
            print("error:", e)
        except IOError as e:
            print(e)
        except Exception as e:
             print("parent class.", e)
        except ArithmeticError as e:
            print("Ar error. ",e)
        except ZeroDivisionError as e:
            print(e)    
        else:
            print("entered integer")
            break
        finally:
            print('all done')
askforint()
# Out:
# enter an int: 0
# parent class. division by zero
# all done
# enter an int: 5
# entered integer
# all done

# %% [markdown]
# ### Raise exception:

# %%
def createexp(a):
    if a ==6:
        raise Exception("Error is", a)
    else:
        print("input ok")
    return a

# %%
createexp(7)
# Out:
# input ok
# 7

# %%
b=createexp(6)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-19-cb0448b12ab9> in <module>
# ----> 1 b=createexp(6)
#
# <ipython-input-17-da373ca273c2> in createexp(a)
#       1 def createexp(a):
#       2     if a ==6:
# ----> 3         raise Exception("Error is", a)
#       4     else:
#       5         print("input ok")
#
# Exception: ('Error is', 6)

# %%
try:
    createexp(6)
except Exception as e:
    print(e)
# Out:
# ('Error is', 6)

# %% [markdown]
# ### Task:

# %% [markdown]
# 1. create mod1.py --- write a logic to print all the even numbers
# 3. call mod1.py, take input from user and try to handle any exceptions
# 4. log all the errors

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
import mod
import logging as lg
lg.basicConfig(filename="even.log", level=lg.ERROR)
while True:
    try:
        ip=int(input("Enter a number: "))
        print(mod.even_num(ip))
        break
    except Exception as e:
        lg.exception(e)
# Out:
# Enter a number: krish
# Enter a number: ok
# Enter a number: test
# Enter a number: 12
# [0, 2, 4, 6, 8, 10, 12]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
